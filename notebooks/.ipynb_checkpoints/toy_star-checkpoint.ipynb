# %%
import matplotlib.pyplot as plt
import sarracen as src
import numpy as np

# %%
sdf_ini = src.read_csv('../Data/initial_distribution/toy_star.csv')

# %%
dm    = 1/sdf_ini.shape[0]
hfact = 1.2
edge  = 0.8

# %%
sdf_ini.params={'mass':dm, 'hfact':hfact}
sdf_ini.calc_density()
sdf_ini
# Out:
# 0          x     y       z  vx  vy  vz      h       rho
# 0    -0.1250 -0.25 -0.6875   0   0   0  0.075  0.575039
# 1    -0.0625 -0.25 -0.6875   0   0   0  0.075  0.575039
# 2     0.0000 -0.25 -0.6875   0   0   0  0.075  0.575039
# 3     0.0625 -0.25 -0.6875   0   0   0  0.075  0.575039
# 4     0.1250 -0.25 -0.6875   0   0   0  0.075  0.575039
# ...      ...   ...     ...  ..  ..  ..    ...       ...
# 7118 -0.1250  0.25  0.6875   0   0   0  0.075  0.575039
# 7119 -0.0625  0.25  0.6875   0   0   0  0.075  0.575039
# 7120  0.0000  0.25  0.6875   0   0   0  0.075  0.575039
# 7121  0.0625  0.25  0.6875   0   0   0  0.075  0.575039
# 7122  0.1250  0.25  0.6875   0   0   0  0.075  0.575039
#
# [7123 rows x 8 columns]

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(sdf_ini['x'], sdf_ini['y'], '.', color='crimson')
plt.xlim(-edge, edge)
plt.ylim(-edge, edge)
#plt.savefig("toy_star_ini_part.png", dpi=300, transparent=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7,5))
ax = sdf_ini.render('rho', ax=ax, rotation=[0,0,0], xlim=[-edge, edge], ylim=[-edge, edge])
ax.set_xticks(np.linspace(-edge, edge, 9))
ax.set_yticks(np.linspace(-edge, edge, 9))
ax.text(-0.7, 0.7, r"$t=0$", color="w")
#plt.savefig("toy_star_ini.png", dpi=300, transparent=True)
plt.show()

# %%
sdf = src.read_csv('../Data/results/toy_star/final.csv')
sdf.params={'mass':dm, 'hfact':hfact}
sdf.calc_density()
sdf
# Out:
# 0            x         y         z        vx        vy        vz         h  \
# 0    -0.122443 -0.234374 -0.599907 -0.000248  0.000077  0.000143  0.090000
# 1    -0.054785 -0.244880 -0.605556  0.000013 -0.000213  0.000212  0.089945
# 2    -0.000000 -0.249233 -0.606946  0.000000 -0.000213  0.000331  0.090190
# 3     0.054785 -0.244880 -0.605556 -0.000013 -0.000213  0.000212  0.089945
# 4     0.122443 -0.234374 -0.599907  0.000248  0.000077  0.000143  0.090000
# ...        ...       ...       ...       ...       ...       ...       ...
# 7118 -0.122443  0.234374  0.599907 -0.000248 -0.000077 -0.000143  0.090000
# 7119 -0.054785  0.244880  0.605556  0.000013  0.000213 -0.000212  0.089945
# 7120  0.000000  0.249233  0.606946  0.000000  0.000213 -0.000331  0.090190
# 7121  0.054785  0.244880  0.605556 -0.000013  0.000213 -0.000212  0.089945
# 7122  0.122443  0.234374  0.599907  0.000248 -0.000077 -0.000143  0.090000
#
# 0            u       rho
# 0     0.015977  0.332772
# ...

# %%
fig, ax = plt.subplots(figsize=(7,5))
ax = sdf.render('rho', ax=ax, rotation=[0,0,0], xlim=[-edge, edge], ylim=[-edge, edge])
ax.set_xticks(np.linspace(-edge, edge, 9))
ax.set_yticks(np.linspace(-edge, edge, 9))
ax.text(-0.7, 0.7, r"$t=16$", color="w")
#plt.savefig("toy_star_fin.png", dpi=300, transparent=True)
plt.show()

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(sdf['x'], sdf['y'], '.', color='crimson')
plt.xlim(-edge, edge)
plt.ylim(-edge, edge)
#plt.savefig("toy_star_fin_part.png", dpi=300, transparent=True)
plt.show()

# %% [markdown]
# # Density Distribution

# %%
def density_theo(r, R, lmbda, k):
    return lmbda/(4*k)*(R**2-r**2)

# %%
R = 0.75
k = 0.05
M = 1.0
n = 1.0
lmbda = 15*M*k/(2*np.pi*R**5) # This value is valid for gamma=2.0

# %%
r = np.linspace(0.001, 1.1*R, 100)
dens = density_theo(r, R, lmbda, k)

# %%
fig = plt.figure(figsize=(6,4))
plt.plot(np.sqrt(sdf['x']**2+sdf['y']**2+sdf['z']**2), sdf['rho'], '.', color='crimson')
plt.plot(r, dens, '--', color='k')
plt.xlim(0., R)
plt.ylim(0., 1.1*lmbda/(4*k)*(R**2))
plt.xlabel("r", fontsize=15)
plt.ylabel(r"$\rho$", fontsize=15)
#plt.savefig("toy_star_density.png", dpi=300, transparent=True)
plt.show()
