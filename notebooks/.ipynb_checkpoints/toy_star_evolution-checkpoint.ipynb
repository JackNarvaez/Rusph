# %%
import matplotlib.pyplot as plt
import sarracen as src
import numpy as np
import pandas as pd

# %% [markdown]
# # Final Setup

# %%
dt = np.dtype([('x', 'double'), ('y', 'double'), ('z', 'double'), ('vx', 'double'), ('vy', 'double'), ('vz', 'double'), ('h', 'double'), ('u', 'double')])

# %%
data = np.fromfile("../Data/results/toy_star/final", dtype=dt)
sdf = src.SarracenDataFrame(pd.DataFrame(data))
dm = 1/sdf.shape[0]
hfact = 1.2

# %%
sdf.params={'mass':dm, 'hfact':hfact}
sdf.calc_density()
sdf
# Out:
#                  x         y         z            vx        vy        vz  \
# 0    -1.224428e-01 -0.234374 -0.599907 -2.483775e-04  0.000077  0.000143
# 1    -5.478471e-02 -0.244880 -0.605556  1.321474e-05 -0.000213  0.000212
# 2    -8.009908e-17 -0.249233 -0.606946  4.382169e-18 -0.000213  0.000331
# 3     5.478471e-02 -0.244880 -0.605556 -1.321474e-05 -0.000213  0.000212
# 4     1.224428e-01 -0.234374 -0.599907  2.483775e-04  0.000077  0.000143
# ...            ...       ...       ...           ...       ...       ...
# 7118 -1.224428e-01  0.234374  0.599907 -2.483775e-04 -0.000077 -0.000143
# 7119 -5.478471e-02  0.244880  0.605556  1.321474e-05  0.000213 -0.000212
# 7120  1.397002e-17  0.249233  0.606946  4.191174e-17  0.000213 -0.000331
# 7121  5.478471e-02  0.244880  0.605556 -1.321474e-05  0.000213 -0.000212
# 7122  1.224428e-01  0.234374  0.599907  2.483775e-04 -0.000077 -0.000143
#
#              h         u       rho
# 0     0.090000  0.015977  0.332772
# 1     0.089945  0.015976  0.333383
# 2     0.090190  0.015981  0.330678
# 3     0.089945  0.015976  0.333383
# 4     0.090000  0.015977  0.332772
# ...        ...       ...       ...
# 7118  0.090000  0.015977  0.332772
# 7119  0.089945  0.015976  0.333383
# 7120  0.090190  0.015981  0.330678
# 7121  0.089945  0.015976  0.333383
# 7122  0.090000  0.015977  0.332772
#
# [7123 rows x 9 columns]

# %%
fig, ax = plt.subplots(figsize=(7,5))
ax = sdf.render('rho', ax=ax, rotation=[0,0,0], xlim=[-0.7, 0.7], ylim=[-0.7, 0.7])
ax.set_xticks(np.linspace(-0.6, 0.6, 7))
ax.set_yticks(np.linspace(-0.6, 0.6, 7))
ax.text(-0.6, 0.6, r"$t=16$", color="w")
plt.show()

# %% [markdown]
# # Angular Momentum Conservation

# %%
# Angular Momentum
def angular_momentum(x, y, z, vx, vy, vz):
    lx = y*vz - z*vy
    ly = z*vx - x*vz
    lz = x*vy - y*vx
    return lx, ly, lz

# Energy
def energy(x, y, z, vx, vy, vz, rho):
    vsq = 0.5 * (vx*vx + vy*vy + vz*vz)
    P = 0.05 * rho*rho
    xsq = 0.5 * (x*x + y*y + z*z)
    return vsq + P + xsq

# %%
time = np.loadtxt("../Data/results/toy_star/Time.txt")
time = np.insert(time, 0, [0.0])
T = len(time)
ang_mom = np.zeros(T)
lin_mom = np.zeros(T)
energ = np.zeros(T)

# Initial Conditions

df = src.read_csv("../Data/initial_distribution/toy_star.csv")
df.params={'mass':dm, 'hfact':hfact}
df.calc_density()
L = np.sum(angular_momentum(df['x'], df['y'], df['z'], df['vx'], df['vy'], df['vz']), axis=1)
ang_mom[0] = np.sqrt(L[0]*L[0] + L[1]*L[1] + L[2]*L[2])
vx = np.sum(df['vx'])
vy = np.sum(df['vy'])
vz = np.sum(df['vz'])
lin_mom[0] = np.sqrt(vx*vx + vy*vy + vz*vz)
energ[0] = np.sum(energy(df['x'], df['y'], df['z'], df['vx'], df['vy'], df['vz'], df['rho']))

for ii in range(0, T-1):
    data = np.fromfile('../Data/results/toy_star/' + str(ii), dtype=dt)
    df = src.SarracenDataFrame(pd.DataFrame(data))
    df.params={'mass':dm, 'hfact':hfact}
    df.calc_density()
    L = np.sum(angular_momentum(df['x'], df['y'], df['z'], df['vx'], df['vy'], df['vz']), axis=1)
    ang_mom[ii+1] = np.sqrt(L[0]*L[0] + L[1]*L[1] + L[2]*L[2])
    vx = np.sum(df['vx'])
    vy = np.sum(df['vy'])
    vz = np.sum(df['vz'])
    lin_mom[ii+1] = np.sqrt(vx*vx + vy*vy + vz*vz)
    energ[ii+1] = np.sum(energy(df['x'], df['y'], df['z'], df['vx'], df['vy'], df['vz'], df['rho']))

# %%
plt.plot(time, np.abs(lin_mom-lin_mom[0]), '-', color='blue')
plt.title("Conservation of Linear Momentum")
plt.xlabel("it [x100]")
plt.ylabel(r"$\frac{|P-P_0|}{m}$")
plt.xlim(0, time[-1])
plt.show()

# %%
plt.plot(time, np.abs(ang_mom-ang_mom[0]), '-', color='crimson')
plt.title("Conservation of Angular Momentum")
plt.xlabel("it [x100]")
plt.ylabel(r"$\frac{|L-L_0|}{m}$")
plt.xlim(0, time[-1])
plt.show()

# %%
plt.plot(time, np.abs((energ-energ[0])/energ[0]), '-', color='forestgreen')
plt.title("Conservation of Energy")
plt.xlabel("it [x100]")
plt.ylabel(r"$\left|\frac{E-E_0}{E_0}\right|$")
plt.xlim(0, time[-1])
plt.show()
