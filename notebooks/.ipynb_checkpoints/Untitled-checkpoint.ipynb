# %%
import numpy as np
import matplotlib.pyplot as plt
#import pandas as pd

x, y, rho = np.genfromtxt('../SPHRust/Data/initial_distribution/ToyStar2D.csv', delimiter=',', dtype=None, skip_header=1, usecols=(1,2,4), unpack=True)

plt.plot(x, y, '.', color='k')
plt.show()

# %%
xn, yn, rhon = np.genfromtxt('../SPHRust/Data/results/ToyStar2D.csv', delimiter=',', dtype=None, skip_header=1, usecols=(1,2,4), unpack=True)

plt.plot(x, y, '.', color='k')
plt.plot(xn, yn, '.', color='crimson')
plt.show()

#0.1

# %%
xn, yn, rhon = np.genfromtxt('../SPHRust/Data/results/ToyStar2D.csv', delimiter=',', dtype=None, skip_header=1, usecols=(1,2,4), unpack=True)

plt.plot(x, y, '.', color='k')
plt.plot(xn, yn, '.', color='orange')
plt.show()

#0.2

# %%
xn, yn, rhon = np.genfromtxt('../SPHRust/Data/results/ToyStar2D.csv', delimiter=',', dtype=None, skip_header=1, usecols=(1,2,4), unpack=True)

plt.plot(x, y, '.', color='k')
plt.plot(xn, yn, '.', color='g')
plt.show()

#0.25

# %%
xn, yn, rhon = np.genfromtxt('../SPHRust/Data/results/ToyStar2D.csv', delimiter=',', dtype=None, skip_header=1, usecols=(1,2,4), unpack=True)

plt.plot(x, y, '.', color='k')
plt.plot(xn, yn, '.', color='b')
plt.show()

#0.28

# %%
xn, yn, rhon = np.genfromtxt('../SPHRust/Data/results/ToyStar2D.csv', delimiter=',', dtype=None, skip_header=1, usecols=(1,2,4), unpack=True)

plt.plot(x, y, '.', color='k')
plt.plot(xn, yn, '.', color='r')
plt.show()

#0.3
