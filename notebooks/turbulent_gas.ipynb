# %%
# Import libraries
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import sarracen as src
import numpy as np
# Out:
# /users/labnet/st2/jjnarvaezcor/virtual-env/lib/python3.8/site-packages/sarracen/kernels/cubic_spline.py:15: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit(fastmath=True)
# /users/labnet/st2/jjnarvaezcor/virtual-env/lib/python3.8/site-packages/sarracen/kernels/quartic_spline.py:15: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit(fastmath=True)
# ...

# %% [markdown]
# # 3D Init Setup

# %%
n = 64**3
dm = 3.814697265625e-06
eta = 1.2

# %%
sdf_ini = src.read_csv('../Data/initial_distribution/hydro64_00020.csv')
sdf_ini.params={'mass':dm, 'hfact':eta}
sdf_ini.calc_density()
sdf_ini
# Out:
# 0              x         y         z        vx        vy        vz         h  \
# 0       0.898855  0.178697  0.129935 -3.187332  2.569930  3.683947  0.022038
# 1       0.922540  0.195456  0.142497 -2.805946  2.604084  3.755596  0.021235
# 2       0.948220  0.212000  0.153798 -2.444464  2.705962  3.655064  0.020422
# 3       0.977433  0.228026  0.163124 -1.961451  3.062362  3.242894  0.019586
# 4       0.009998  0.243326  0.169273 -1.775910  3.396255  2.348700  0.018074
# ...          ...       ...       ...       ...       ...       ...       ...
# 262139  0.861764  0.036106  0.098495 -1.910838 -0.727902  3.066224  0.017644
# 262140  0.869059  0.067357  0.110980 -1.633763  0.235920  3.511239  0.017888
# 262141  0.873820  0.097220  0.124637 -2.486653  1.256359  4.041788  0.020140
# 262142  0.885975  0.121538  0.135871 -3.668859  1.516066  4.018480  0.022617
# 262143  0.907941  0.144982  0.147165 -3.148153  1.799306  4.050891  0.022503
#
# 0              m       rho
# ...

# %%
fig, ax = plt.subplots(figsize=(7,6))
ax = sdf_ini.render('rho', xsec=0.5, ax=ax, rotation=[0,0,0], log_scale=True, vmin=1e-2, vmax=10)
ax.set_xticks(np.arange(0, 1.1, step=0.2))
ax.set_yticks(np.arange(0, 1.1, step=0.2))
#plt.savefig("turbulentgasini.png")

# %% [markdown]
# # Final Setup

# %%
sdf = src.read_csv('../Data/results/turbulent_gas/8.csv')
sdf.params={'mass':dm, 'hfact':eta}
sdf.calc_density()
sdf
# Out:
# 0              x         y         z        vx        vy        vz         h  \
# 0       0.773902  0.181848  0.199860 -5.120445  0.179813  0.552758  0.007450
# 1       0.812505  0.186527  0.182323 -3.583102 -0.761761  0.536775  0.006171
# 2       0.832735  0.221065  0.151981 -3.822586  0.418820 -0.812919  0.004672
# 3       0.909201  0.241479  0.198515 -1.741851 -1.002336 -1.450745  0.006036
# 4       0.934844  0.304130  0.214991 -1.619714  0.208654  0.943884  0.008441
# ...          ...       ...       ...       ...       ...       ...       ...
# 262139  0.796462  0.023360  0.204292 -0.547384 -0.169377  1.890699  0.018069
# 262140  0.824544  0.079847  0.245083 -0.191907  0.576618  2.798245  0.016900
# 262141  0.763982  0.119877  0.267877 -4.363621 -0.881488  2.036218  0.009787
# 262142  0.753538  0.116895  0.246853 -5.537514 -1.768902  2.351067  0.008104
# 262143  0.764194  0.127543  0.241491 -4.976483 -1.820312  2.564773  0.006511
#
# 0               u        rho
# ...

# %%
fig, ax = plt.subplots(figsize=(7,6))
ax = sdf.render('rho', xsec=0.5, ax=ax, rotation=[0,0,0], log_scale=True, vmin=1e-2, vmax=10)
ax.set_xticks(np.arange(0, 1.1, step=0.2))
ax.set_yticks(np.arange(0, 1.1, step=0.2))

# %%
fig, ax = plt.subplots(figsize=(7,6))
ax = sdf.render('rho', xsec=0.5, ax=ax, rotation=[0,0,0], log_scale=True, vmin=1e-2, vmax=10)
ax = sdf.arrowplot(['vx', 'vy', 'vz'], color='gray')
ax.set_xticks(np.arange(0, 1.1, step=0.2))
ax.set_yticks(np.arange(0, 1.1, step=0.2))
#plt.savefig("turbulentgasfin.png")

# %% [markdown]
# # Final Setup

# %%
plt.scatter(sdf['x'], sdf['y'], c=sdf['rho'], cmap='inferno', s=5)
# Add a colorbar
plt.colorbar()
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()

# %% [markdown]
# # Conservation's Laws

# %%
# Angular Momentum
def angular_momentum(x, y, z, vx, vy, vz):
    lx = y*vz - z*vy
    ly = z*vx - x*vz
    lz = x*vy - y*vx
    return lx, ly, lz

# Energy
def energy(vx, vy, vz):
    return 0.5*(vx*vx + vy*vy + vz*vz)

# %%
T = 133
time = range(0, T)
ang_mom = np.zeros(T)
lin_mom = np.zeros(T)
energ = np.zeros(T)

for ii in range(1, T+1):
    df = src.read_csv('../Data/results/turbulent_gas/' + str(ii) + ".csv")
    df.params={'mass':dm, 'hfact':eta}
    df.calc_density()
    L = np.sum(angular_momentum(df['x'], df['y'], df['z'], df['vx'], df['vy'], df['vz']), axis=1)
    ang_mom[ii-1] = np.sqrt(L[0]*L[0] + L[1]*L[1] + L[2]*L[2])
    vx = np.sum(df['vx'])
    vy = np.sum(df['vy'])
    vz = np.sum(df['vz'])
    lin_mom[ii-1] = np.sqrt(vx*vx + vy*vy + vz*vz)
    energ[ii-1] = np.sum(energy(df['vx'], df['vy'], df['vz']))

# %%
plt.plot(time[:], np.abs((lin_mom[:]-lin_mom[0])/lin_mom[0]), '-', color='blue')
plt.title("Conservation of Linear Momentum")
plt.xlabel("it [x100]")
plt.ylabel(r"$\frac{|P-P_0|}{P_0}$")
plt.xlim(0, T)
plt.show()

# %%
plt.plot(time[:], np.abs((ang_mom[:]-ang_mom[0])/ang_mom[0]), '-', color='crimson')
plt.title("Conservation of Angular Momentum")
plt.xlabel("it [x100]")
plt.ylabel(r"$\frac{|L-L_0|}{L_0}$")
plt.xlim(0, T)
plt.show()

# %%
plt.plot(time[:], np.abs((energ[:]-energ[0])/energ[0]), '-', color='forestgreen')
plt.title("Conservation of Energy")
plt.xlabel("it [x100]")
plt.ylabel(r"$\left|\frac{E-E_0}{E_0}\right|$")
plt.xlim(0, T)
plt.show()

# %%
plt.plot(time[:], energ[:], '-', color='forestgreen')
plt.title("Conservation of Energy")
plt.xlabel("it [x100]")
plt.ylabel(r"$E$")
plt.xlim(0, T)
plt.yscale("log")
plt.show()

# %%
sdf.calc_density()

sdf.lineplot('rho', xlim=(0, 1), ylim=0.5, zlim=0.)
# Out:
# <Axes: xlabel='cross-section (x, y, z)', ylabel='rho'>
