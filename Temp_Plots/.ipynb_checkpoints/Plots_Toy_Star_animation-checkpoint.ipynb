# %%
import matplotlib.pyplot as plt
import sarracen as src
import numpy as np

# %%
sdf = src.read_csv('../Data/results/toy_star/7300.csv')
sdf.params={'mass':2.0/100}
sdf
# Out:
# 0          x         y        vx        vy         u         h       rho
# 0   0.061703  0.420874 -0.002757  0.000936  0.021629  0.140106  1.467164
# 1   0.408524  0.438542 -0.001886 -0.002577  0.018754  0.188360  0.811735
# 2   0.402830  0.155063 -0.000009 -0.001686  0.049362  0.140738  1.454015
# 3   0.387238  0.243287  0.001992 -0.007975  0.072127  0.145630  1.357975
# 4  -0.416576  0.421215 -0.001337  0.000649  0.021471  0.184257  0.848286
# ..       ...       ...       ...       ...       ...       ...       ...
# 95 -0.080194 -0.073512  0.002211 -0.006618  0.061965  0.115534  2.157618
# 96 -0.126453  0.133648 -0.001373  0.002392  0.037595  0.118207  2.061147
# 97 -0.457609  0.198092 -0.001897  0.002390 -0.008384  0.153021  1.229952
# 98  0.217883 -0.317904 -0.000913  0.000607  0.007629  0.133851  1.607489
# 99 -0.278999  0.515207 -0.002091  0.002116  0.020886  0.181290  0.876288
#
# [100 rows x 7 columns]

# %%
sdf.render('rho', xsec=1.0)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
# Angular Momentum
def angular_momentum(x, y, vx, vy):
    return x*vy - y*vx

# %%
T = 73
time = range(0, T)
ang_mom = np.zeros(T)

fig = plt.figure()

for ii in range(1, T+1):
    df = src.read_csv('../Data/results/toy_star/' + str(ii*100) + ".csv")
    df.params={'mass': 2.0/df.shape[0]}
    ax1 = fig.add_subplot(1,1,1)
    plot_df = df.render('rho', ax= ax1, xsec=1.0)
    ax1.set_xlim(-1, 1)
    ax1.set_ylim(-1, 1)
    fig.savefig("../Data/results/toy_star/images/image_" + str(ii) + ".png")
    ax1.cla()
    plt.clf()
    ang_mom[ii-1] = np.sum(angular_momentum(df['x'], df['y'], df['vx'], df['vy']))
plt.show()

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(time, ang_mom, '-', color='crimson')
plt.show()
