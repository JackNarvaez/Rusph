# %%
# Import libraries
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import sarracen as src
import numpy as np
# Out:
# /users/labnet/st2/jjnarvaezcor/virtual-env/lib/python3.8/site-packages/sarracen/kernels/cubic_spline.py:15: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit(fastmath=True)
# /users/labnet/st2/jjnarvaezcor/virtual-env/lib/python3.8/site-packages/sarracen/kernels/quartic_spline.py:15: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit(fastmath=True)
# /users/labnet/st2/jjnarvaezcor/virtual-env/lib/python3.8/site-packages/sarracen/kernels/quintic_spline.py:15: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit(fastmath=True)

# %% [markdown]
# # 3D Init Setup

# %%
n = 32**3
dm = 3.0517578125e-05
eta = 1.2

# %%
sdf_ini = src.read_csv('../Data/initial_distribution/hydro32_00020.csv')
sdf_ini.params={'mass':dm, 'hfact':eta}
sdf_ini.calc_density()
sdf_ini
# Out:
# 0             x         y         z        vx        vy        vz         h  \
# 0      0.900668  0.184204  0.108731 -2.593622  2.256404  2.567266  0.041070
# 1      0.944303  0.217114  0.137733 -2.818519  2.837712  3.304874  0.045177
# 2      0.002433  0.246422  0.151454 -2.223370  3.700157  2.261867  0.043559
# 3      0.065630  0.261394  0.145854 -1.692933  4.186088  0.410532  0.041286
# 4      0.132742  0.270060  0.135807 -0.574638  5.437574 -0.540051  0.042511
# ...         ...       ...       ...       ...       ...       ...       ...
# 32763  0.843741  0.881597  0.077668 -5.755281 -5.038882  3.323175  0.036969
# 32764  0.855897  0.938685  0.082505 -4.617552 -3.349844  3.294612  0.041052
# 32765  0.870260  0.997155  0.097236 -3.428760 -1.964753  3.198069  0.038580
# 32766  0.892612  0.061304  0.118140 -2.618515 -0.220715  3.631402  0.038323
# 32767  0.919915  0.119243  0.145313 -2.934497  1.242817  4.247772  0.045012
#
# 0             m       rho
# 0      0.000031  0.761235
# 1      0.000031  0.571913
# 2      0.000031  0.638076
# 3      0.000031  0.749346
# 4      0.000031  0.686417
# ...         ...       ...
# 32763  0.000031  1.043721
# 32764  0.000031  0.762224
# 32765  0.000031  0.918347
# 32766  0.000031  0.936960
# 32767  0.000031  0.578245
#
# [32768 rows x 9 columns]

# %%
fig, ax = plt.subplots(figsize=(7,5))
ax = sdf_ini.render('rho', xsec=0.5, ax=ax, rotation=[0,0,0])

# %% [markdown]
# # Final Setup

# %%
sdf = src.read_csv('../Data/results/turbulent_gas/final.csv')
sdf.params={'mass':dm, 'hfact':eta}
sdf.calc_density()
sdf
# Out:
# 0             x         y         z        vx        vy        vz         h  \
# 0      0.672058  0.086987  0.185639 -2.492806 -1.678765  0.565007  0.017139
# 1      0.778083  0.183062  0.135454 -2.478122 -0.346009 -0.153017  0.030140
# 2      0.881940  0.267982  0.120000 -1.853782 -1.678464  0.078743  0.030702
# 3      0.113554  0.423811  0.101994  2.256175  0.444311  0.954823  0.037530
# 4      0.103115  0.603284  0.079348  0.767031  3.003340  0.606772  0.039578
# ...         ...       ...       ...       ...       ...       ...       ...
# 32763  0.574757  0.866333  0.254813 -0.804376  1.313567  0.356491  0.027593
# 32764  0.654860  0.833938  0.247481 -0.275019  0.561216  1.699872  0.043310
# 32765  0.752746  0.794194  0.195684 -0.525850 -1.466170  0.357967  0.025589
# 32766  0.876599  0.915380  0.290712  2.741866 -2.346529  0.210976  0.029270
# 32767  0.878473  0.159631  0.340620  2.923579  0.482621  0.472957  0.041529
#
# 0              u        rho
# 0      39.617901  10.474896
# 1      36.132671   1.926003
# 2      36.471208   1.822111
# 3      35.414056   0.997593
# 4      27.743220   0.850642
# ...          ...        ...
# 32763  34.495239   2.510106
# 32764  26.755261   0.649136
# 32765  31.865501   3.147276
# 32766  25.172403   2.103023
# 32767  32.168546   0.736288
#
# [32768 rows x 9 columns]

# %%
fig, ax = plt.subplots(figsize=(7,5))
ax = sdf.render('rho', xsec=0.5, ax=ax, rotation=[0,0,0])

# %%
fig, ax = plt.subplots(figsize=(7,5))
ax = sdf.render('rho', xsec=0.5, ax=ax, rotation=[0,0,0])
ax = sdf.arrowplot(['vx', 'vy', 'vz'], color='y')

# %% [markdown]
# # Final Setup

# %%
plt.scatter(sdf['x'], sdf['y'], c=sdf['rho'], cmap='inferno', s=5)
# Add a colorbar
plt.colorbar()
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()

# %% [markdown]
# # Conservation's Laws

# %%
# Angular Momentum
def angular_momentum(x, y, z, vx, vy, vz):
    lx = y*vz - z*vy
    ly = z*vx - x*vz
    lz = x*vy - y*vx
    return lx, ly, lz

# %%
T = 43
time = range(0, T)
ang_mom = np.zeros(T)
lin_mom = np.zeros(T)
energ = np.zeros(T)

for ii in range(1, T+1):
    df = src.read_csv('../Data/results/turbulent_gas/' + str(ii) + ".csv")
    L = np.sum(angular_momentum(df['x'], df['y'], df['z'], df['vx'], df['vy'], df['vz']), axis=1)
    ang_mom[ii-1] = np.sqrt(L[0]*L[0] + L[1]*L[1] + L[2]*L[2])
    vx = np.sum(df['vx'])
    vy = np.sum(df['vy'])
    vz = np.sum(df['vz'])
    lin_mom[ii-1] = np.sqrt(vx*vx + vy*vy + vz*vz)
    energ[ii-1] = 0.5*lin_mom[ii-1] + np.sum(df['u'])

# %%
plt.plot(time[:], np.abs((lin_mom[:]-lin_mom[0])/lin_mom[0]), '-', color='blue')
plt.title("Conservation of Linear Momentum")
plt.xlabel("it [x100]")
plt.ylabel(r"$\frac{|P-P_0|}{P_0}$")
plt.xlim(0, T)
plt.show()

# %%
plt.plot(time[:], np.abs((ang_mom[:]-ang_mom[0])/ang_mom[0]), '-', color='crimson')
plt.title("Conservation of Angular Momentum")
plt.xlabel("it [x100]")
plt.ylabel(r"$\frac{|L-L_0|}{L_0}$")
plt.xlim(0, T)
plt.show()

# %%
plt.plot(time[:], np.abs((energ[:]-energ[0])/energ[0]), '-', color='forestgreen')
plt.title("Conservation of Energy")
plt.xlabel("it [x100]")
plt.ylabel(r"$\left|\frac{E-E_0}{E_0}\right|$")
plt.xlim(0, T)
plt.show()

# %%
sdf.calc_density()

sdf.lineplot('rho', xlim=(-0.5, 0.5), ylim=-0.1875, zlim=0.0)
# Out:
# <Axes: xlabel='cross-section (x, y, z)', ylabel='rho'>
