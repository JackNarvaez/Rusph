# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import sarracen as src
import numpy as np

# %% [markdown]
# # Initial Setup

# %%
sdf = src.read_csv('../Data/results/kelvin_helmholtz/final.csv')
sdf.params={'mass':0.00125}
sdf
# Out:
# 0            x         y        vx        vy         u         h       rho
# 0     0.998448  0.000005  0.073926 -0.034558  3.686220  0.052645  0.649463
# 1     0.999317  0.750210  0.359567  0.052024  3.755056  0.040636  1.090085
# 2     0.998828  0.049295  0.245483 -0.176676  3.605275  0.045233  0.879753
# 3     0.998094  0.799899  0.034699 -0.023963  3.682097  0.044499  0.909036
# 4     0.998289  0.100093  0.094281  0.024360  3.630761  0.045205  0.880833
# ...        ...       ...       ...       ...       ...       ...       ...
# 1195  0.985186  0.593748  0.884141 -0.000152  1.825854  0.031115  1.838248
# 1196  0.985188  0.625004  0.884281  0.001319  1.825398  0.031348  1.831392
# 1197  0.985181  0.656277  0.881639  0.002496  1.831419  0.031156  1.854337
# 1198  0.985207  0.687242  0.891951 -0.071523  1.842158  0.031142  1.855942
# 1199  0.985296  0.717792  0.922343 -0.240602  1.785021  0.031439  1.821062
#
# [1200 rows x 7 columns]

# %%
sdf.render('rho', xsec=1.0)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# # Final Setup

# %%
sdft = src.read_csv('../Data/results/kelvin_helmholtz/final.csv')
sdft.params={'mass':0.00125}
sdft
# Out:
# 0            x         y        vx        vy         u         h       rho
# 0     0.998448  0.000005  0.073926 -0.034558  3.686220  0.052645  0.649463
# 1     0.999317  0.750210  0.359567  0.052024  3.755056  0.040636  1.090085
# 2     0.998828  0.049295  0.245483 -0.176676  3.605275  0.045233  0.879753
# 3     0.998094  0.799899  0.034699 -0.023963  3.682097  0.044499  0.909036
# 4     0.998289  0.100093  0.094281  0.024360  3.630761  0.045205  0.880833
# ...        ...       ...       ...       ...       ...       ...       ...
# 1195  0.985186  0.593748  0.884141 -0.000152  1.825854  0.031115  1.838248
# 1196  0.985188  0.625004  0.884281  0.001319  1.825398  0.031348  1.831392
# 1197  0.985181  0.656277  0.881639  0.002496  1.831419  0.031156  1.854337
# 1198  0.985207  0.687242  0.891951 -0.071523  1.842158  0.031142  1.855942
# 1199  0.985296  0.717792  0.922343 -0.240602  1.785021  0.031439  1.821062
#
# [1200 rows x 7 columns]

# %%
plt.scatter(sdft['x'], sdft['y'], c=sdft['vy'], cmap='inferno', s=5)
plt.colorbar()
#plt.clim(1.0, 2.0)
plt.show()

# %% [markdown]
# # Angular Momentum's Conservation

# %%
# Angular Momentum
def angular_momentum(x, y, vx, vy):
    return x*vy - y*vx

# %%
T = 106
time = range(0, T)
ang_mom = np.zeros(T)

for ii in range(1, T+1):
    df = src.read_csv('../Data/results/kelvin_helmholtz/' + str(ii) + ".csv")
    df.params={'mass': 2.0/df.shape[0]}
    ang_mom[ii-1] = np.sum(angular_momentum(df['x'], df['y'], df['vx'], df['vy']))

# %%
plt.plot(time[:-1], np.abs(ang_mom[:-1]-ang_mom[0]), '-', color='crimson')
plt.title("Conservation of Angular Momentum")
plt.xlabel("it [x100]")
plt.ylabel("$|L-L_0|$")
plt.xlim(0, T-1)
plt.show()

# %% [markdown]
# # Conservation of Energy

# %%
# Energy
def energy(vx, vy, u):
    return 0.5*(vx*vx + vy*vy)+u

# %%
energ = np.zeros(T)

for ii in range(1, T+1):
    df = src.read_csv('../Data/results/kelvin_helmholtz/' + str(ii) + ".csv")
    energ[ii-1] = np.sum(energy(df['vx'], df['vy'], df['u']))

# %%
plt.plot(time[:], np.abs((energ[:]-energ[0])/energ[0]), '-', color='crimson')
plt.title("Conservation of Energy")
plt.xlabel("it [x100]")
plt.ylabel(r"$\left|\frac{E-E_0}{E_0}\right|$")
plt.xlim(0, T-1)
plt.show()
