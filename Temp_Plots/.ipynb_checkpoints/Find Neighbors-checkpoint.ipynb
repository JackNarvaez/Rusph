# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
tree = pd.read_csv('../Data/tree_algorithm/set_tree.csv')
sdf = pd.read_csv('../Data/tree_algorithm/set_particles.csv')
tree
# Out:
#        x_min     y_min      side  depth    n
# 0   0.000000  0.000000  1.000000      0  100
# 1   0.000000  0.000000  0.500000      1   32
# 2   0.000000  0.000000  0.500000      2   32
# 3   0.000000  0.000000  0.166667      3    1
# 4   0.166667  0.000000  0.166667      3    0
# ..       ...       ...       ...    ...  ...
# 73  0.583333  0.833333  0.083333      5    2
# 74  0.500000  0.916667  0.083333      5    2
# 75  0.583333  0.916667  0.083333      5    1
# 76  0.666667  0.833333  0.166667      4    2
# 77  0.833333  0.833333  0.166667      4    1
#
# [78 rows x 5 columns]

# %%
from matplotlib.patches import Rectangle

col=["k","blue", "green", "red", "orange"]
fig = plt.figure(figsize=(8,8))
#add rectangle
for i in range(tree.shape[0]):
    plt.gca().add_patch(Rectangle((tree["x_min"][i],tree["y_min"][i]),tree["side"][i],tree["side"][i],
                    edgecolor=col[tree["depth"][i]-1],
                    facecolor='none',
                    lw=1))
plt.plot(sdf['x'], sdf['y'], '.', color='crimson')
#plt.xlim(0, 1)
#plt.ylim(0, 1)
plt.show()

# %%
part = pd.read_csv('../Data/tree_algorithm/set_neighbors.csv')
particle = part["p"][0]
neightbors = part["p"][1:]

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(sdf['x'][particle], sdf['y'][particle], '.', color='crimson')
#plt.plot(sdf['x'][neightbors], sdf['y'][neightbors], '.', color='blue')
plt.show()
