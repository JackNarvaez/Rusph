# %%
import sarracen as src
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
sdf_ini = pd.read_csv('../SPHRust/Data/initial_distribution/Rand_Square.csv')
sdf_n = pd.read_csv('../SPHRust/Data/results/Rand_Square.csv')

fig = plt.figure(figsize=(5,5))
plt.plot(sdf_n['x'], sdf_n['y'], '.', color='k')
plt.plot(sdf_ini['x'], sdf_ini['y'], '.', color='crimson')
#plt.xlim(0, 1)
#plt.ylim(0, 1)
plt.show()

# %%
sdf = src.read_csv('../SPHRust/Data/results/Rand_Square.csv')
sdf
# Out:
# 0     m         x         y        vx        vy         u         h        rho
# 0   0.1  0.511958  0.997847 -1.397627 -0.346629 -0.463689  0.140476   7.297095
# 1   0.1  0.931223  0.005152 -0.151385 -0.193280 -0.664874  0.167905   5.107837
# 2   0.1  0.024816  0.018736 -0.100226 -0.289824 -0.535164  0.160478   5.591553
# 3   0.1  0.750782  0.150116 -1.686239  1.041971 -0.291866  0.123443   9.449976
# 4   0.1  0.296422  0.018959 -0.292192  0.331239  0.029335  0.141985   7.142978
# ..  ...       ...       ...       ...       ...       ...       ...        ...
# 95  0.1  0.420217  0.116501  0.049220  0.564990 -0.040351  0.124192   9.336309
# 96  0.1  0.504731  0.058990 -0.141303  0.184556 -0.100015  0.116177  10.668858
# 97  0.1  0.359259  0.033693 -1.206868  0.291206 -0.079414  0.127564   8.849265
# 98  0.1  0.630054  0.273747 -0.634210 -0.011086 -0.031006  0.129701   8.559972
# 99  0.1  0.854086  0.143152 -0.008293  0.960666  0.000000  0.135767   7.812255
#
# [100 rows x 8 columns]

# %%
sdf.render('rho', xsec=0.0)
# Out:
# <Axes: xlabel='x', ylabel='y'>
