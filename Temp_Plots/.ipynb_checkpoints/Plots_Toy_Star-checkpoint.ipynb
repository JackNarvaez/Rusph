# %%
import matplotlib.pyplot as plt
import sarracen as src
import numpy as np

# %%
sdf = src.read_csv('../Data/results/toy_star/final.csv')
sdf.params={'mass':2.0/100}
sdf
# Out:
# 0          x         y        vx        vy         u         h       rho
# 0  -0.150807 -0.058841  0.000064 -0.000586  0.834349  0.117333  2.091945
# 1  -0.035688 -0.411064  0.004411 -0.001107  1.537453  0.137813  1.516402
# 2   0.587018 -0.089479  0.000452 -0.000424  0.837597  0.185102  0.840562
# 3  -0.232868 -0.127349 -0.000475 -0.001110  1.001230  0.122418  1.921787
# 4  -0.411191  0.160035  0.000236 -0.000638  1.408890  0.142966  1.409045
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.282023 -0.105329  0.000642  0.001214  1.356125  0.125334  1.833389
# 96  0.492107 -0.320764  0.000227 -0.000215  1.205368  0.181793  0.871442
# 97  0.087986 -0.151667 -0.000635 -0.000589  1.143122  0.117519  2.085329
# 98  0.016755  0.028966 -0.000539 -0.000555  0.853581  0.113992  2.216392
# 99  0.157922  0.252674 -0.000640  0.000784  1.452039  0.125000  1.843193
#
# [100 rows x 7 columns]

# %%
sdf.render('rho', xsec=1.0)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(sdf['x'], sdf['y'], '.', color='crimson')
plt.show()

# %%
def density_theo(r, R, lmbda, k):
    return lmbda/(4*k)*(R**2-r**2)

# %%
R = 0.75
k = 0.1
M = 2.0
n = 1.0
lmbda = 2*k / (np.pi**(1/n)) * (M*(1+n)/R**2)**(1+1/n)/M

# %%
r = np.linspace(0.001, 1.1*R, 100)
dens = density_theo(r, R, lmbda, k)

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(np.sqrt(sdf['x']**2+sdf['y']**2), sdf['rho'], '.', color='crimson')
plt.plot(r, dens, '--', color='k')
plt.show()
