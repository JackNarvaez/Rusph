# %%
import matplotlib.pyplot as plt
import sarracen as src
import numpy as np

# %%
sdf = src.read_csv('../Data/results/toy_star/final.csv')
sdf.params={'mass':2.0/100}
sdf
# Out:
# 0          x         y        vx        vy         u         h       rho
# 0  -0.153529 -0.051991  0.000972 -0.002545  0.834170  0.117319  2.092466
# 1  -0.047721 -0.411383  0.001850  0.000966  1.534790  0.138098  1.510137
# 2   0.584702 -0.094388 -0.000294  0.003651  0.841081  0.183906  0.851533
# 3  -0.228981 -0.117367 -0.000903 -0.003218  1.004842  0.121881  1.938739
# 4  -0.415266  0.160819  0.003690  0.001236  1.402937  0.143811  1.392543
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.279201 -0.113962 -0.000249  0.002288  1.355697  0.125341  1.833181
# 96  0.492430 -0.325817  0.000942  0.004105  1.201741  0.183015  0.859844
# 97  0.090369 -0.142625  0.000886 -0.002846  1.144297  0.117322  2.092341
# 98  0.016055  0.035763  0.001481 -0.002376  0.852211  0.114114  2.211643
# 99  0.162105  0.247740 -0.002243  0.001207  1.451220  0.124878  1.846795
#
# [100 rows x 7 columns]

# %%
sdf.render('rho', xsec=1.0)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(sdf['x'], sdf['y'], '.', color='crimson')
plt.show()

# %%
def density_theo(r, R, lmbda, k):
    return lmbda/(4*k)*(R**2-r**2)

# %%
R = 0.75
k = 0.1
M = 2.0
n = 1.0
lmbda = 2*k / (np.pi**(1/n)) * (M*(1+n)/R**2)**(1+1/n)/M

# %%
r = np.linspace(0.001, 1.1*R, 100)
dens = density_theo(r, R, lmbda, k)

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(np.sqrt(sdf['x']**2+sdf['y']**2), sdf['rho'], '.', color='crimson')
plt.plot(r, dens, '--', color='k')
plt.show()
