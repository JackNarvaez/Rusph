# %%
import matplotlib.pyplot as plt
import sarracen as src
import numpy as np
# Out:
# /users/labnet/st2/jjnarvaezcor/virtual-env/lib/python3.8/site-packages/sarracen/kernels/cubic_spline.py:15: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit(fastmath=True)
# /users/labnet/st2/jjnarvaezcor/virtual-env/lib/python3.8/site-packages/sarracen/kernels/quartic_spline.py:15: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit(fastmath=True)
# /users/labnet/st2/jjnarvaezcor/virtual-env/lib/python3.8/site-packages/sarracen/kernels/quintic_spline.py:15: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit(fastmath=True)

# %%
sdf = src.read_csv('../Data/results/accretion_disk_2D.csv')
sdf.params={'mass':2.0/100}
sdf
# Out:
# 0          x         y  vx  vy  u        h  rho
# 0   0.659762  0.000000   0   0  0  0.01026    1
# 1   0.659762  0.020520   0   0  0  0.01026    1
# 2   0.659762  0.041039   0   0  0  0.01026    1
# 3   0.659762  0.061559   0   0  0  0.01026    1
# 4   0.659762  0.082079   0   0  0  0.01026    1
# 5   0.659762  0.102599   0   0  0  0.01026    1
# 6   0.659762  0.123118   0   0  0  0.01026    1
# 7   0.659762  0.143638   0   0  0  0.01026    1
# 8   0.659762  0.164158   0   0  0  0.01026    1
# 9   0.659762  0.184677   0   0  0  0.01026    1
# 10  0.680282  0.000000   0   0  0  0.01026    1
# 11  0.680282  0.020520   0   0  0  0.01026    1
# 12  0.680282  0.041039   0   0  0  0.01026    1
# 13  0.680282  0.061559   0   0  0  0.01026    1
# 14  0.680282  0.082079   0   0  0  0.01026    1
# 15  0.680282  0.102599   0   0  0  0.01026    1
# 16  0.680282  0.123118   0   0  0  0.01026    1
# 17  0.680282  0.143638   0   0  0  0.01026    1
# 18  0.680282  0.164158   0   0  0  0.01026    1
# 19  0.680282  0.184677   0   0  0  0.01026    1

# %%
sdf.render('rho', xsec=1.0)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(sdf['x'], sdf['y'], '.', color='crimson')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 fig = plt.figure(figsize=(8,8))
#       2 plt.plot(sdf['x'], sdf['y'], '.', color='crimson')
# ----> 3 plt.xlims(-1, 1)
#       4 plt.ylims(-1, 1)
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlims'

# %%
def density_theo(r, R, lmbda, k):
    return lmbda/(4*k)*(R**2-r**2)

# %%
R = 0.75
k = 0.1
M = 2.0
n = 1.0
lmbda = 2*k / (np.pi**(1/n)) * (M*(1+n)/R**2)**(1+1/n)/M

# %%
r = np.linspace(0.001, 1.1*R, 100)
dens = density_theo(r, R, lmbda, k)

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(np.sqrt(sdf['x']**2+sdf['y']**2), sdf['rho'], '.', color='crimson')
plt.plot(r, dens, '--', color='k')
plt.show()
